# %%
import pandas as pd

# %%
orders_read1 = pd.read_csv('../req_implement/req-implement.txt', encoding='ISO-8859-5', sep='\t',header=None, parse_dates=[1], dayfirst=True)

# %%
orders_read1.sort_values(by=[1])
# Out:
#             0          1        2                                   3   \
# 9688   5454225 2020-10-14  3146924               Жидкость Л CVTF нк.1л
# 9773   5454217 2021-03-10  3148662  Масло L GEN UNIVER 10W40 нк.4л ТАФ
# 10370  5454252 2021-04-23  3048582   Масло Л АВ ПРОФ LS5 10W40 б.170кг
# 3811   5453287 2021-05-14   103813  Масло Л АВ 20W50 CF-4/SG; б.216,5л
# 8516   5455876 2021-05-24  3052110             СОЖ Л ФРЕО МП 15Л к.20л
# ...        ...        ...      ...                                 ...
# 7143   5456802 2022-05-11   157578                Масло Л ВГ; б.216,5л
# 7144   5456802 2022-05-11   211086        Масло Л ИНТЕГО 460; б.216,5л
# 7145   5456805 2022-05-11  3170707   Жидкость Л ГЕЙЗЕР HFDU 46 б.185кг
# 99     5456803 2022-05-11   203951      Масло Л ГЕЙЗЕР СТ 46; б.216,5л
# 7570   5456809 2022-05-11   199904      Масло Л ГЕЙЗЕР ЦФ 32; б.216,5л
#
#               4          5      6   \
# 9688     292,668    292,668  0,000
# 9773     616,320    616,320  0,000
# ...

# %%
from datetime import datetime
custom_date_parser = lambda x: datetime.strptime(x, '%d-%m-%Y')

# %%
orders_read2 = pd.read_csv('../req_implement/req-implement.txt', encoding='ISO-8859-5', sep='\t',header=None,
                           parse_dates=[1])

# %%
orders_read2
# Out:
#             0          1        2                                         3   \
# 0      5454298 2022-03-21  3048570         Масло Л АВ ПРОФ XLA 10W30 б.175кг
# 1      5454301 2022-03-21    17775       Масло Л ТРАНС ТМ-5, 75W90; б.216,5л
# 2      5453392 2022-03-21   203899  Масло Л ГЕЙЗЕР ММ 30 (SAE 30W); б.216,5л
# 3      5453396 2022-03-21  3289611              Жидкость Л ATF IIIH; б.175кг
# 4      5453401 2022-03-23    18739         Масло TEBOIL SYPRES 220; б.216,5л
# ...        ...        ...      ...                                       ...
# 10496  5456381 2022-05-05  3162967          Смазка Л УНИФЛЕКС 2-150 кар.0,4л
# 10497  5456381 2022-05-05  3124196            Смазка Л УНИФЛЕКС 2-150; в.20л
# 10498  5456381 2022-05-05  3182210              Масло Л АВ 40 CF/CD/SF к.20л
# 10499  5456381 2022-05-05  1462833   Масло Л АВАНГАРД 40, CF/CD/SF; б.216,5л
# 10500  5456381 2022-05-05  3033626          Масло Л АВ 15W40 CF-4/SG б.180кг
#
# ...

# %%
pd.to_datetime(orders_read2[1]).dt.strftime('%d-%m-%Y')
# Out:
# 0        21-03-2022
# 1        21-03-2022
# 2        21-03-2022
# 3        21-03-2022
# 4        23-03-2022
#             ...
# 10496    05-05-2022
# 10497    05-05-2022
# 10498    05-05-2022
# 10499    05-05-2022
# 10500    05-05-2022
# Name: 1, Length: 10501, dtype: object

# %%
orders_read2
# Out:
# 0        21-Mar-22 00:00
# 1        21-Mar-22 00:00
# 2        21-Mar-22 00:00
# 3        21-Mar-22 00:00
# 4        23-Mar-22 00:00
#               ...
# 10496    05-May-22 00:00
# 10497    05-May-22 00:00
# 10498    05-May-22 00:00
# 10499    05-May-22 00:00
# 10500    05-May-22 00:00
# Name: 1, Length: 10501, dtype: object
